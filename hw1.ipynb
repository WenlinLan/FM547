# %%
import numpy as np
K = 9100
Premium_call = 179
Premium_put = 185

Interval = 1000
ST = np.arange(K - Interval, K + Interval)

Payoff_longcall = np.maximum(ST - K, 0) - Premium_call

Payoff_shortcall = - Payoff_longcall

import matplotlib.pyplot as plt

plt.plot(ST,Payoff_longcall)
plt.plot(ST,Payoff_shortcall)

plt.show()

# %%
import numpy as np
K = 9100
Premium_call = 179
Premium_put = 185

Interval = 1000
ST = np.arange(K - Interval, K + Interval)

Payoff_longput = np.maximum(K - ST, 0) - Premium_put


Payoff_shortput = - Payoff_longput

import matplotlib.pyplot as plt

plt.plot(ST,Payoff_longput)
plt.plot(ST,Payoff_shortput)

plt.show()

# %%
K1 = 8900
K2 = 9400
import numpy as np
K = 9100
ST = np.arange(K - Interval, K + Interval)

Bull_Payoff_longcall = np.maximum(ST - K1, 0) - Premium_call

Bull_Payoff_shortcall = - np.maximum(ST - K2, 0) + Premium_call


plt.plot(ST,Bull_Payoff_longcall)
plt.plot(ST,Bull_Payoff_shortcall)
plt.plot(ST,Bull_Payoff_longcall + Bull_Payoff_shortcall)
plt.show()
